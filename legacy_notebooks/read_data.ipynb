# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train2electricboogaloo.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426340 entries, 0 to 426339
# Data columns (total 12 columns):
# ProdID            426340 non-null object
# NumProdReviews    426340 non-null int64
# UserId            426340 non-null object
# NumUserReviews    426340 non-null int64
# HelpfulRatio      426340 non-null float64
# FoundHelpful      426340 non-null int64
# HelpfulVotes      426340 non-null int64
# Score             426340 non-null int64
# Time              426340 non-null int64
# Summary           426320 non-null object
# Text              426340 non-null object
# SumTxt            426340 non-null object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 39.0+ MB

# %%
train.describe()
# Out:
#        NumProdReviews  NumUserReviews   HelpfulRatio   FoundHelpful  \
# count   426340.000000   426340.000000  426340.000000  426340.000000
# mean        74.434719        8.544415       0.407594       1.733159
# std        105.265732       21.907385       0.461946       7.328184
# min          1.000000        1.000000       0.000000       0.000000
# 25%          6.000000        1.000000       0.000000       0.000000
# 50%         24.000000        3.000000       0.000000       0.000000
# 75%        103.000000        7.000000       1.000000       2.000000
# max        667.000000      326.000000       3.000000     844.000000
#
#         HelpfulVotes          Score          Time
# count  426340.000000  426340.000000  4.263400e+05
# mean        2.220244       4.183455  1.296222e+09
# std         8.014894       1.310577  4.808061e+07
# min         0.000000       1.000000  9.408096e+08
# 25%         0.000000       4.000000  1.271203e+09
# 50%         1.000000       5.000000  1.311034e+09
# ...

# %%
train.Summary.fillna('', inplace=True)
train.Text.fillna('', inplace=True)
train.SumTxt.fillna('', inplace=True)

# %%
train.head()
# Out:
#        ProdID  NumProdReviews          UserId  NumUserReviews  HelpfulRatio  \
# 0  B0034EDLS2             249   AVF82BC7S0IO7               5           0.0
# 1  B001I7HJE4               1  A1YUL9PCJR3JTY             312           1.0
# 2  B000LKTB90              44  A1BBPP1EC75JX4               1           0.0
# 3  B001HXJPS2               3   A5QSI9MNS8NMS               4           0.0
# 4  B006H34CUS             251  A20IBAIRSNBEAQ               1           0.0
#
#    FoundHelpful  HelpfulVotes  Score        Time  \
# 0             0             0      5  1332806400
# 1             1             1      5  1190160000
# 2             0             0      5  1285977600
# 3             0             0      5  1338163200
# 4             0             0      5  1343606400
#
#                                              Summary  \
# 0                                          Very Good
# 1  Organic, Kosher, Tasty Assortment of Premium T...
# ...

# %%
train.loc[0]
# Out:
# ProdID                                                   B0034EDLS2
# NumProdReviews                                                  249
# UserId                                                AVF82BC7S0IO7
# NumUserReviews                                                    5
# HelpfulRatio                                                      0
# FoundHelpful                                                      0
# HelpfulVotes                                                      0
# Score                                                             5
# Time                                                     1332806400
# Summary                                                   Very Good
# Text              I received this product early from the seller!...
# SumTxt            Very Good I received this product early from t...
# Name: 0, dtype: object

# %%
train.loc[1]
# Out:
# ProdID                                                   B001I7HJE4
# NumProdReviews                                                    1
# UserId                                               A1YUL9PCJR3JTY
# NumUserReviews                                                  312
# HelpfulRatio                                                      1
# FoundHelpful                                                      1
# HelpfulVotes                                                      1
# Score                                                             5
# Time                                                     1190160000
# Summary           Organic, Kosher, Tasty Assortment of Premium T...
# Text              ***** Numi's Collection Assortment Melange inc...
# SumTxt            Organic, Kosher, Tasty Assortment of Premium T...
# Name: 1, dtype: object

# %%
train.loc[1,'Text']
# Out:
# '***** Numi\'s Collection Assortment Melange includes: 5 Herbal Teas (caffeine-free, also called ""teasans""): * Dry Desert Lime: Lime Herbal Teasan * Fields of Gold: Lemongrass Herbal Teasan * Red Mellow Bush: Rooibos Herbal Teasan * Bushmen\'s Brew: Honeybush Herbal Teasan * Simply Mint: Moroccan Mint  2 Green Teas (lower in caffeine): * Temple of Heaven: Gunpowder Green Tea * Monkey King: Jasmine Green Tea  2 Black Teas (contain caffeine): * Chinese Breakfast: Yunnan Black Tea * Smoky Tarry: Lapsang Souchong Black Tea  This is a total of nine different teas, two tea bags of each one in each box. Numi teas are known for their high-quality, organic and kosher ingredients, and in my opinion, are some of the tastiest and best teas I have ever tried. They do not include artificial ingredients or flavorings.  On the box, the manufacturer writes: ""From mist-covered mountains to sun-drenched deserts to fertile fields, we proudly bring you our tea palette. The flavors range from smooth ea
# ...

# %%
train.loc[1,'SumTxt']
# Out:
# 'Organic, Kosher, Tasty Assortment of Premium Teas & Teasans ***** Numi\'s Collection Assortment Melange includes: 5 Herbal Teas (caffeine-free, also called ""teasans""): * Dry Desert Lime: Lime Herbal Teasan * Fields of Gold: Lemongrass Herbal Teasan * Red Mellow Bush: Rooibos Herbal Teasan * Bushmen\'s Brew: Honeybush Herbal Teasan * Simply Mint: Moroccan Mint  2 Green Teas (lower in caffeine): * Temple of Heaven: Gunpowder Green Tea * Monkey King: Jasmine Green Tea  2 Black Teas (contain caffeine): * Chinese Breakfast: Yunnan Black Tea * Smoky Tarry: Lapsang Souchong Black Tea  This is a total of nine different teas, two tea bags of each one in each box. Numi teas are known for their high-quality, organic and kosher ingredients, and in my opinion, are some of the tastiest and best teas I have ever tried. They do not include artificial ingredients or flavorings.  On the box, the manufacturer writes: ""From mist-covered mountains to sun-drenched deserts to fertile fields, we proudly
# ...

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
train.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdc3b020210>,
# ...
#       dtype=object)

# %%
# import nltk as nltk

# %%
# nltk.download('wordnet')

# %%
# from sklearn.feature_extraction.text import CountVectorizer

# %%
# vect =  CountVectorizer()

# %%
# vect.fit(train['SumTxt'])

# %%
# len(vect.vocabulary_)

# %%
# vect.vocabulary_

# %%
train['Score'].value_counts().plot(kind='bar', figsize = (10, 10))

# %%
train2['Score'] = train['Score']
train2.head()
train.groupby(['Score']).count().plot(kind = 'bar')

# groupby(['Score']).count().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-8c4d63441f93> in <module>()
#       1 train2['Score'] = train['Score']
#       2 train2.head()
# ----> 3 train2.groupby(['Score']).count().plot(kind = 'bar')
#       4
#       5 # groupby(['Score']).count().plot(kind='bar')
#
# /home/swagmaster/anaconda3/envs/atab/lib/python3.7/site-packages/pandas/core/groupby/generic.py in count(self)
#    1316             Count of values within each group.
#    1317         """
# -> 1318         ids, _, ngroups = self.grouper.group_info
#    1319         val = self.obj._internal_get_values()
#    1320
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /home/swagmaster/anaconda3/envs/atab/lib/python3.7/site-packages/pandas/core/groupby/ops.py in group_info(self)
#     294     @cache_readonly
#     295     def group_info(self):
# ...

# %%
train['Score'].plot.bar(figsize=(10,10))

# %%
train['Score'].hist(figsize=(10,10), bins = 5)

# %%
train.plot.scatter(x = 'Score', y = 'FoundHelpful', figsize=(10,8))

# %%
train.plot.scatter(x = 'Score', y = 'FoundHelpful', figsize=(10,8))

# %%
train.plot.scatter(x = 'Score', y = 'HelpfulVotes', figsize=(10,6))

# %%
train.plot.scatter(x = 'Score', y = 'NumProdReviews', figsize=(10,8))

# %%
train.plot.scatter(x = 'Score', y = 'NumUserReviews', figsize=(10,8))

# %%
from pandas.plotting import scatter_matrix

attributes = ["HelpfulRatio", "Score", "Time",
              "FoundHelpful", "HelpfulVotes", "NumUserReviews", "NumProdReviews"]

# %%
scatter_matrix(train[attributes], figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f05bc815650>,
# ...
#       dtype=object)
